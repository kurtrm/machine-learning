# %%
"""Notebook consisting of an analysis of imperfect data
   in Seattle and NOAA data sets.
"""
# Out:
# 'Notebook consisting of an analysis of imperfect data\n   in Seattle and NOAA data sets.\n'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
NOAA = pd.read_csv("NOAA_data.csv")

# %%
#  Need to format the Date to match the fremont dates
NOAA['DATE'] = pd.to_datetime(NOAA['DATE'].astype(str))

# %%
NOAA.rename(columns={'DATE': 'Date'}, inplace=True)

# %%
NOAA.set_index('Date')
# Out:
#                       STATION         STATION_NAME  PRCP    SNWD    SNOW  \
# Date
# 2013-01-01  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-02  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-03  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-04  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.27 -9999.0 -9999.0
# 2013-01-05  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0 -9999.0
# 2013-01-06  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.07 -9999.0 -9999.0
# 2013-01-07  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.07 -9999.0 -9999.0
# 2013-01-08  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.04 -9999.0 -9999.0
# 2013-01-09  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.84 -9999.0 -9999.0
# 2013-01-10  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.24 -9999.0 -9999.0
# 2013-01-11  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.04 -9999.0 -9999.0
# 2013-01-12  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-13  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-14  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-15  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-16  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-17  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-18  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-19  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-20  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-21  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-22  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-23  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2013-01-24  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.31 -9999.0 -9999.0
# 2013-01-25  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.19 -9999.0 -9999.0
# 2013-01-26  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.18 -9999.0 -9999.0
# 2013-01-27  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.09 -9999.0 -9999.0
# 2013-01-28  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.04 -9999.0 -9999.0
# 2013-01-29  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.33 -9999.0 -9999.0
# 2013-01-30  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.45 -9999.0 -9999.0
# ...                       ...                  ...   ...     ...     ...
# 2015-03-28  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.01 -9999.0 -9999.0
# 2015-03-29  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0 -9999.0
# 2015-03-30  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2015-03-31  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.06 -9999.0 -9999.0
# 2015-04-01  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.17 -9999.0 -9999.0
# 2015-04-02  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.19 -9999.0 -9999.0
# 2015-04-03  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.01 -9999.0 -9999.0
# 2015-04-04  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.02 -9999.0 -9999.0
# 2015-04-05  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.01 -9999.0 -9999.0
# 2015-04-06  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0 -9999.0
# 2015-04-07  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2015-04-08  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.03 -9999.0 -9999.0
# 2015-04-09  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.01 -9999.0 -9999.0
# 2015-04-10  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0 -9999.0
# 2015-04-12  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.04 -9999.0 -9999.0
# 2015-04-13  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0 -9999.0
# 2015-04-14  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.39 -9999.0 -9999.0
# 2015-04-15  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.01 -9999.0 -9999.0
# 2015-04-16  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2015-04-17  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2015-04-27  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0 -9999.0
# 2015-04-28  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2015-04-29  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.09 -9999.0 -9999.0
# 2015-04-30  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.01 -9999.0 -9999.0
# 2015-05-01  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2015-05-02  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2015-05-03  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2015-05-04  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.00 -9999.0     0.0
# 2015-05-05  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.07 -9999.0 -9999.0
# 2015-05-06  GHCND:US1WAKG0188  SEATTLE 3.3 N WA US  0.44 -9999.0 -9999.0
#
#               WESF
# Date
# 2013-01-01 -9999.0
# 2013-01-02 -9999.0
# 2013-01-03 -9999.0
# 2013-01-04 -9999.0
# 2013-01-05 -9999.0
# 2013-01-06 -9999.0
# 2013-01-07 -9999.0
# 2013-01-08 -9999.0
# 2013-01-09 -9999.0
# 2013-01-10 -9999.0
# 2013-01-11 -9999.0
# 2013-01-12 -9999.0
# 2013-01-13 -9999.0
# 2013-01-14 -9999.0
# 2013-01-15 -9999.0
# 2013-01-16 -9999.0
# 2013-01-17 -9999.0
# 2013-01-18 -9999.0
# 2013-01-19 -9999.0
# 2013-01-20 -9999.0
# 2013-01-21 -9999.0
# 2013-01-22 -9999.0
# 2013-01-23 -9999.0
# 2013-01-24 -9999.0
# 2013-01-25 -9999.0
# 2013-01-26 -9999.0
# 2013-01-27 -9999.0
# 2013-01-28 -9999.0
# 2013-01-29 -9999.0
# 2013-01-30 -9999.0
# ...            ...
# 2015-03-28 -9999.0
# 2015-03-29 -9999.0
# 2015-03-30 -9999.0
# 2015-03-31 -9999.0
# 2015-04-01 -9999.0
# 2015-04-02 -9999.0
# 2015-04-03 -9999.0
# 2015-04-04 -9999.0
# 2015-04-05 -9999.0
# 2015-04-06 -9999.0
# 2015-04-07 -9999.0
# 2015-04-08 -9999.0
# 2015-04-09 -9999.0
# 2015-04-10 -9999.0
# 2015-04-12 -9999.0
# 2015-04-13 -9999.0
# 2015-04-14 -9999.0
# 2015-04-15 -9999.0
# 2015-04-16 -9999.0
# 2015-04-17 -9999.0
# 2015-04-27 -9999.0
# 2015-04-28 -9999.0
# 2015-04-29 -9999.0
# 2015-04-30 -9999.0
# 2015-05-01 -9999.0
# 2015-05-02 -9999.0
# 2015-05-03 -9999.0
# 2015-05-04 -9999.0
# 2015-05-05 -9999.0
# 2015-05-06 -9999.0
#
# [702 rows x 6 columns]

# %%
NOAA.columns
# Out:
# Index(['STATION', 'STATION_NAME', 'Date', 'PRCP', 'SNWD', 'SNOW', 'WESF'], dtype='object')

# %%
NOAA_date_and_prcp = NOAA[['Date', 'PRCP']]

# %%
NOAA_date_and_prcp.set_index('Date')
# Out:
#             PRCP
# Date
# 2013-01-01  0.00
# 2013-01-02  0.00
# 2013-01-03  0.00
# 2013-01-04  0.27
# 2013-01-05  0.00
# 2013-01-06  0.07
# 2013-01-07  0.07
# 2013-01-08  0.04
# 2013-01-09  0.84
# 2013-01-10  0.24
# 2013-01-11  0.04
# 2013-01-12  0.00
# 2013-01-13  0.00
# 2013-01-14  0.00
# 2013-01-15  0.00
# 2013-01-16  0.00
# 2013-01-17  0.00
# 2013-01-18  0.00
# 2013-01-19  0.00
# 2013-01-20  0.00
# 2013-01-21  0.00
# 2013-01-22  0.00
# 2013-01-23  0.00
# 2013-01-24  0.31
# 2013-01-25  0.19
# 2013-01-26  0.18
# 2013-01-27  0.09
# 2013-01-28  0.04
# 2013-01-29  0.33
# 2013-01-30  0.45
# ...          ...
# 2015-03-28  0.01
# 2015-03-29  0.00
# 2015-03-30  0.00
# 2015-03-31  0.06
# 2015-04-01  0.17
# 2015-04-02  0.19
# 2015-04-03  0.01
# 2015-04-04  0.02
# 2015-04-05  0.01
# 2015-04-06  0.00
# 2015-04-07  0.00
# 2015-04-08  0.03
# 2015-04-09  0.01
# 2015-04-10  0.00
# 2015-04-12  0.04
# 2015-04-13  0.00
# 2015-04-14  0.39
# 2015-04-15  0.01
# 2015-04-16  0.00
# 2015-04-17  0.00
# 2015-04-27  0.00
# 2015-04-28  0.00
# 2015-04-29  0.09
# 2015-04-30  0.01
# 2015-05-01  0.00
# 2015-05-02  0.00
# 2015-05-03  0.00
# 2015-05-04  0.00
# 2015-05-05  0.07
# 2015-05-06  0.44
#
# [702 rows x 1 columns]

# %%
fremont_bike_count = pd.read_csv("fremont-bike-count.csv")

# %%
fremont_bike_count.columns
# Out:
# Index(['Date', 'Fremont Bridge West Sidewalk', 'Fremont Bridge East Sidewalk'], dtype='object')

# %%
number_of_nulls = fremont_bike_count.isnull().sum()  # Just for my info

# %%
#  I chose to fill the null fields with the median value

# %%
filled_fremont_bike_count = fremont_bike_count.fillna(fremont_bike_count[['Fremont Bridge East Sidewalk',
                                              'Fremont Bridge West Sidewalk']].median())

# %%
nulls_in_filled = filled_fremont_bike_count.isnull().sum()  # For my info

# %%
filled_fremont_bike_count.columns
# Out:
# Index(['Date', 'Fremont Bridge West Sidewalk', 'Fremont Bridge East Sidewalk'], dtype='object')

# %%
#  Now I need to aggregate the hours into days for the bridge data
filled_fremont_bike_count['Date'] = pd.to_datetime(filled_fremont_bike_count['Date'])

# %%
filled_fremont_bike_count.columns
# Out:
# Index(['Date', 'Fremont Bridge West Sidewalk', 'Fremont Bridge East Sidewalk'], dtype='object')

# %%
aggregated_bike_count = (filled_fremont_bike_count
.set_index(pd.DatetimeIndex(filled_fremont_bike_count['Date']))
.groupby(pd.TimeGrouper('D'))
.aggregate(np.sum)
.reset_index())

# %%
aggregated_bike_count.columns
# Out:
# Index(['Date', 'Fremont Bridge West Sidewalk', 'Fremont Bridge East Sidewalk'], dtype='object')

# %%
NOAA_date_and_prcp.columns
# Out:
# Index(['Date', 'PRCP'], dtype='object')

# %%
bridge_and_precip_daily = aggregated_bike_count.merge(NOAA_date_and_prcp) # This took me forever to figure out

# %%
#  Chose to aggregate monthly as this would make a graph a little easier to manage
bridge_and_precip_monthly = (bridge_and_precip_daily
.set_index(pd.DatetimeIndex(bridge_and_precip_daily['Date']))
.groupby(pd.TimeGrouper('M'))
.aggregate(np.sum)
.reset_index())

# %%
xlabels = bridge_and_precip_monthly['Date'].dt.strftime('%b \'%y')

# %%
bar_chart = bridge_and_precip_monthly[['Date',
                           'Fremont Bridge East Sidewalk',
                           'Fremont Bridge West Sidewalk']].plot.bar().set_xticklabels(xlabels, rotation=90)

# %%
plt.show()

# %%
plt.title("Bike Crossings By Month 1/2013-5/2015")
plt.xlabel("Month")
plt.ylabel("# Bikes Crossing Fremont Bridge Northbound/Southbound")

# %%
southbound = bridge_and_precip_monthly['Fremont Bridge West Sidewalk']
northbound = bridge_and_precip_monthly['Fremont Bridge East Sidewalk']
month = bridge_and_precip_monthly['Date']
